# %%
<DOCTYPE HTML>
<html>
<head>
<title> text</title>
</head>
<body>
<b>this text is bolded </b><br>
<u>this text is underlined</u><br>
<mark> this text is highlighted</mark><br>
this is a normal text<sup>this will be superscripted</sup>this is normal again<br>
this is a normal text<sub>this will be subscripted</sub>this is normal again<br>
normal text <small> small text</small><br>
<del>this text is deleted</del>
</body>
</html>

# %%
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Navigate Me</title>
</head>
<body>

    <h1>Navigate Me:</h1>

    <p>Take me to <a href="https://pwskills.com" target="_blank">PW Skills</a> to buy a course.</p>
    <p>Take me to <a href="https://developer.mozilla.org" target="_blank">MDN docs</a> to know more about Web Development.</p>
    <p>Take me to <a href="https://lab.pwskills.com" target="_blank">PW Skills Lab</a> to practice live coding.</p>

</body>
</html>

# %%
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Home</title>
</head>
<body>

    <nav>
        <a href="index.html">Home</a> |
        <a href="web-development.html">Web Development</a> |
        <a href="web-design.html">Web Design</a>
    </nav>

    <h1>Welcome to My Blog</h1>
    <p>Hi, I'm Apoorva Sharma, a B.Tech CSE student passionate about full-stack development.</p>

</body>
</html>




<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Web Development</title>
</head>
<body>

    <nav>
        <a href="index.html">Home</a> |
        <a href="web-development.html">Web Development</a> |
        <a href="web-design.html">Web Design</a>
    </nav>

    <h1>Web Development</h1>
    <p>Web development involves creating websites and applications using HTML, CSS, JavaScript, and frameworks.</p>

</body>
</html>





<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Web Design</title>
</head>
<body>

    <nav>
        <a href="index.html">Home</a> |
        <a href="web-development.html">Web Development</a> |
        <a href="web-design.html">Web Design</a>
    </nav>

    <h1>Web Design</h1>
    <p>Web design focuses on the visual and user experience aspects of a website, including layout and aesthetics.</p>

</body>
</html>

# %%
<ol>
    <li><strong>&lt;h1&gt; - &lt;h6&gt;</strong>: Defines headings of different levels.</li>
    <li><strong>&lt;p&gt;</strong>: Represents a paragraph.</li>
    <li><strong>&lt;a&gt;</strong>: Creates a hyperlink.</li>
    <li><strong>&lt;img&gt;</strong>: Embeds an image.</li>
    <li><strong>&lt;ul&gt; &amp; &lt;ol&gt;</strong>: Unordered and ordered lists.</li>
</ol>

# %%
<dl>
    <dt><strong>HTML</strong></dt>
    <dd>The backbone of web pages, used to structure content.</dd>

    <dt><strong>CSS</strong></dt>
    <dd>Styles the web page, making it visually appealing.</dd>

    <dt><strong>JavaScript</strong></dt>
    <dd>Adds interactivity and functionality to web pages.</dd>

    <dt><strong>React</strong></dt>
    <dd>A JavaScript library for building UI components efficiently.</dd>

    <dt><strong>Node.js</strong></dt>
    <dd>Allows JavaScript to run on the server-side.</dd>
</dl>

# %%
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Full Stack Web Development</title>
</head>
<body>

    <h1>Full Stack Web Development</h1>

    <ol>
        <li><strong>HTML</strong></li>
        <table border="1">
            <tr>
                <th>Primary Use Cases</th>
                <th>Key Features/Benefits</th>
            </tr>
            <tr>
                <td>Building the structure of web pages</td>
                <td>
                    <ul>
                        <li>Simple and easy to learn</li>
                        <li>Compatible with all web browsers</li>
                        <li>Allows for semantic markup</li>
                    </ul>
                </td>
            </tr>
        </table>

        <li><strong>CSS</strong></li>
        <table border="1">
            <tr>
                <th>Primary Use Cases</th>
                <th>Key Features/Benefits</th>
            </tr>
            <tr>
                <td>Styling and layout of web pages</td>
                <td>
                    <ul>
                        <li>Allows for separation of content and presentation</li>
                        <li>Enables responsive design</li>
                        <li>Offers a wide range of styling options</li>
                    </ul>
                </td>
            </tr>
        </table>

        <li><strong>JavaScript</strong></li>
        <table border="1">
            <tr>
                <th>Primary Use Cases</th>
                <th>Key Features/Benefits</th>
            </tr>
            <tr>
                <td>Adding interactivity and functionality to web pages</td>
                <td>
                    <ul>
                        <li>Enables dynamic content updates</li>
                        <li>Used for client-side and server-side scripting</li>
                        <li>Supports various frameworks like React and Angular</li>
                    </ul>
                </td>
            </tr>
        </table>
    </ol>

</body>
</html>

# %%
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Table of Contents</title>
</head>
<body>

    <h1>Table of Contents</h1>

    <ul>
        <li><a href="#">Part 1: Introduction</a></li>

        <li><a href="#">Part 2: Getting Started</a>
            <ul>
                <li><a href="#">2.1 Installing the Software</a></li>
                <li><a href="#">2.2 Creating a New Project</a>
                    <ul>
                        <li><a href="#">2.2.1 Project Templates</a></li>
                        <li><a href="#">2.2.2 Customizing Settings</a></li>
                    </ul>
                </li>
                <li><a href="#">2.3 Exploring the Interface</a>
                    <ul>
                        <li><a href="#">2.3.1 Toolbar Features</a></li>
                        <li><a href="#">2.3.2 Panel Layout</a>
                            <ul>
                                <li><a href="#">2.3.2.1 Docking Panels</a></li>
                                <li><a href="#">2.3.2.2 Tabbed Interface</a></li>
                            </ul>
                        </li>
                    </ul>
                </li>
            </ul>
        </li>

        <li><a href="#">Part 3: Advanced Topics</a>
            <ul>
                <li><a href="#">3.1 Working with Plugins</a>
                    <ul>
                        <li><a href="#">3.1.1 Installing Plugins</a></li>
                        <li><a href="#">3.1.2 Plugin Configuration</a></li>
                    </ul>
                </li>
                <li><a href="#">3.2 Customizing the UI</a>
                    <ul>
                        <li><a href="#">3.2.1 Changing Themes</a></li>
                        <li><a href="#">3.2.2 Configuring Shortcuts</a></li>
                    </ul>
                </li>
                <li><a href="#">3.3 Optimizing Performance</a>
                    <ul>
                        <li><a href="#">3.3.1 Caching Strategies</a></li>
                        <li><a href="#">3.3.2 Resource Minification</a></li>
                    </ul>
                </li>
            </ul>
        </li>

        <li><a href="#">Part 4: Conclusion

# %%
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Conference Schedule</title>
</head>
<body>

    <h1>Conference Schedule</h1>

    <table border="1" cellpadding="10">
        <tr>
            <th>Time</th>
            <th>Room 1</th>
            <th>Room 2</th>
            <th>Room 3</th>
            <th>Room 4</th>
        </tr>
        <tr>
            <td rowspan="2">9:00 AM - 10:00 AM</td>
            <td rowspan="2">Keynote</td>
            <td>Session A</td>
            <td>Session B</td>
            <td rowspan="2">Session C</td>
        </tr>
        <tr>
            <td>Session D</td>
            <td>Session E</td>
        </tr>
        <tr>
            <td>10:30 AM - 11:30 AM</td>
            <td colspan="3">Session F</td>
            <td></td>
        </tr>
        <tr>
            <td>12:00 PM - 1:00 PM</td>
            <td colspan="4">Lunch Break</td>
        </tr>
        <tr>
            <td rowspan="2">1:00 PM - 2:00 PM</td>
            <td>Session G</td>
            <td>Session H</td>
            <td>Session I</td>
            <td>Session J</td>
        </tr>
        <tr>
            <td>Session K</td>
            <td></td>
            <td>Session L</td>
            <td>Session M</td>
        </tr>
    </table>

</body>
</html>
